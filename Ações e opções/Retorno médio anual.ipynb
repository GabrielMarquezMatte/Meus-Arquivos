# %%
library(IntroCompFinR)
# Out:
# Loading required package: xts
# Loading required package: zoo
# Warning message:
# "package 'zoo' was built under R version 3.6.2"
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo

# %%
ativos <- c("PRIO3", "MGLU3", "BPAN4", "WIZS3")

trpl_ret <- c(0.1788,0.455,0.0822,0.2295,0.3819)
abev_ret <- c(0.1371,-0.0496,0.331,-0.2559,0.2408)
itsa_ret <- c(-0.1265,0.3931,0.3762,0.3262,0.2740)
enat_ret <- c(-0.1464,-0.0524,1.0703,-0.0024,0.9465)
seer_ret <- c(-0.7195,1.4738,0.7105,-0.4898,0.9836)
oibr_ret <- c(-0.7372,0.095,0.3827,-0.5387,-0.3120)
tcsa_ret <- c(-0.2432,-0.0446,-0.0374,-0.2961,0.2661)
petr_ret <- c(-0.2815,1.2132,0.0829,0.4591,0.3687)
vale_ret <- c(-0.3573,0.9826,0.6256,0.3111,0.0685)
itub_ret <- c(-0.1094,0.4903,0.2964,0.3241,0.1198)
b3sa_ret <- c(0.2198,0.5525,0.4049,0.2079,0.6326)
mglu_ret <- c(-0.6967,5.0378,5.0921,1.2639,1.1219)
vvar_ret <- c(-0.7955,1.4861,1.2123-0.4457,1.5444)
lren_ret <- c(0.1391,0.3828,0.7091,0.2089,0.4750)
rent_ret <- c(-0.2848,0.4142,1.0540,0.3613,0.6875)
suzb_ret <- c(0.7291,-0.2235,0.3650,1.0473,0.0534)
egie_ret <- c(0.0628,0.0705,0.0931,0.2998,0.5920)
enbr_ret <- c(0.3969,0.2299,0.0522,0.0923,0.5696)
flry_ret <- c(0,1.3794,0.6891,-0.3099,0.6188)
hype_ret <- c(0.3398,0.2245,0.4773,-0.1193,0.2177)
pssa_ret <- c(-0.0259,-0.0287,0.4046,0.5575,0.2463)
wizs_ret <- c(-0.2909,0.4966,-0.1054,-0.3719,1.3034)
bpan_ret <- c(-0.2922,-0.2065,0.4634,0.0722,4.4923)
abcb_ret <- c(-0.2794,0.7739,0.3336,0.0564,0.2682)
caml_ret <- c(0,0,-0.1144,-0.0799,0.3039)
mdia_ret <- c(-0.2399,0.7503,0.3726,-0.1718,-0.1086)
bees_ret <- c(0.0146,0.5395,0.5327,0.2042,0.5949)
brsr_ret <- c(-0.2354,0.3301,1.3937,-0.1072,0.1269)
prio_ret <- c(-0.4409,0.7724,2.7523,0.2127,2.3327)
taee_ret <- c(0.0062,0.4071,0.1094,0.2545,0.4089)
cdi_ret <- c(0.1077,0.1325,0.1394,0.0990,0.0640,0.0594)
wti_ret <- c(-0.3106,0.4365,0.1155,-0.2445,0.3624)
gold_ret <- c(-0.1038,0.0843,0.1313,-0.0156)
ficverde_ret <- c(0.4727,-0.1682,0.1463,0.064,0.2586)
mult_ret <- c(-0.0333,-0.1668,0.5842,0.2331,0.0219,0.3745)
odpv_ret <- c(0.0493,-0.0081,0.3686,0.3128,-0.1105,0.2664)
ativos_t <- c("TRPL4","ABEV3","ITSA4","ENAT3","SEER3","OIBR4","TCSA4","PETR4","VALE3","ITUB4","B3SA3","MGLU3","VVAR3","LREN3","RENT3","SUZB3","EGIE3","ENBR3","FLRY3","HYPE3","PSSA4","WIZS3","BPAN4","ABCB4","CAML3","MDIA3","BEES3","BRSR3","PRIO3","TAEE11", "CDI", "WTI", "GOLD", "FIC Verde", "MULT3", "ODPV3")

# %%
retorno_t <- cbind(trpl_ret, abev_ret, itsa_ret, enat_ret, seer_ret, oibr_ret, tcsa_ret, petr_ret, vale_ret, itub_ret, b3sa_ret, mglu_ret, vvar_ret, lren_ret, rent_ret, suzb_ret, egie_ret, enbr_ret, flry_ret, hype_ret, pssa_ret, wizs_ret, bpan_ret, abcb_ret, caml_ret, mdia_ret, bees_ret, brsr_ret, prio_ret, taee_ret, cdi_ret, wti_ret, gold_ret, ficverde_ret, mult_ret, odpv_ret)
colnames(retorno_t) <- ativos_t
retorno_t
# Out:
# Warning message in cbind(trpl_ret, abev_ret, itsa_ret, enat_ret, seer_ret, oibr_ret, :
# "number of rows of result is not a multiple of vector length (arg 1)"
#      TRPL4  ABEV3   ITSA4   ENAT3   SEER3   OIBR4   TCSA4   PETR4   VALE3
# [1,] 0.1788  0.1371 -0.1265 -0.1464 -0.7195 -0.7372 -0.2432 -0.2815 -0.3573
# [2,] 0.4550 -0.0496  0.3931 -0.0524  1.4738  0.0950 -0.0446  1.2132  0.9826
# [3,] 0.0822  0.3310  0.3762  1.0703  0.7105  0.3827 -0.0374  0.0829  0.6256
# [4,] 0.2295 -0.2559  0.3262 -0.0024 -0.4898 -0.5387 -0.2961  0.4591  0.3111
# [5,] 0.3819  0.2408  0.2740  0.9465  0.9836 -0.3120  0.2661  0.3687  0.0685
# [6,] 0.1788  0.1371 -0.1265 -0.1464 -0.7195 -0.7372 -0.2432 -0.2815 -0.3573
#      ITUB4   ... BEES3  BRSR3   PRIO3   TAEE11 CDI    WTI     GOLD    FIC Verde
# [1,] -0.1094 ... 0.0146 -0.2354 -0.4409 0.0062 0.1077 -0.3106 -0.1038  0.4727
# [2,]  0.4903 ... 0.5395  0.3301  0.7724 0.4071 0.1325  0.4365  0.0843 -0.1682
# ...

# %%
retorno_medio_t <- rbind(mean(retorno_t[,1]),mean(retorno_t[,2]),mean(retorno_t[,3]),mean(retorno_t[,4]),mean(retorno_t[,5]),mean(retorno_t[,6]),mean(retorno_t[,7]),mean(retorno_t[,8]),mean(retorno_t[,9]),mean(retorno_t[,10]),mean(retorno_t[,11]),mean(retorno_t[,12]),mean(retorno_t[,13]),mean(retorno_t[,14]),mean(retorno_t[,15]),mean(retorno_t[,16]),mean(retorno_t[,17]),mean(retorno_t[,18]),mean(retorno_t[,19]),mean(retorno_t[,20]),mean(retorno_t[,21]),mean(retorno_t[,22]),mean(retorno_t[,23]),mean(retorno_t[,24]),mean(retorno_t[,25]),mean(retorno_t[,26]),mean(retorno_t[,27]),mean(retorno_t[,28]),mean(retorno_t[,29]),mean(retorno_t[,30]), mean(retorno_t[,31]), mean(retorno_t[,32]), mean(retorno_t[,33]), mean(retorno_t[,34]), mean(retorno_t[,35]), mean(retorno_t[,36]))
rownames(retorno_medio_t) <- ativos_t
retorno_medio_t
# Out:
#           [,1]
# TRPL4      0.251033333
# ABEV3      0.090083333
# ITSA4      0.186083333
# ENAT3      0.278200000
# SEER3      0.206516667
# OIBR4     -0.307900000
# TCSA4     -0.099733333
# PETR4      0.260150000
# VALE3      0.212200000
# ITUB4      0.168633333
# B3SA3      0.372916667
# MGLU3      1.853716667
# VVAR3      0.615366667
# LREN3      0.342333333
# RENT3      0.324566667
# SUZB3      0.450066667
# EGIE3      0.196833333
# ENBR3      0.289633333
# FLRY3      0.396233333
# HYPE3      0.246633333
# PSSA4      0.187983333
# WIZS3      0.123483333
# BPAN4      0.706166667
# ABCB4      0.145550000
# CAML3      0.018266667
# MDIA3      0.060450000
# BEES3      0.316750000
# BRSR3      0.212116667
# PRIO3      0.864716667
# TAEE11     0.198716667
# CDI        0.100333333
# WTI        0.008116667
# GOLD       0.012783333
# FIC Verde  0.207683333
# MULT3      0.168933333
# ODPV3      0.146416667
